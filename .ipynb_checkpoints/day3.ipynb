# %%
import cv2
import skimage as ski 
import matplotlib.pyplot as plt

# %%
img = cv2.imread('v.png.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (455, 640, 3)

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 =plt.imread('v.png.jpg')
plt.imshow(img1)

# %%
img2= plt.imread('v.png.jpg')
plt.imshow(img2)

# %%
ski.io.imsave('myfile.png',img)
plt.imsave('myfile2.png',img)
cv2.imwrite('myfile3.png',img)
# Out:
# True

# %%
img_gray
